# %% [markdown]
# # Is Seattle Weather Getting More Extreme?
#
# ## 1. Introduction
#
# ### Background
# For many years, climate change has been an area of focus for environmental groups, governments and concerned citizens around the globe. In recent years, extreme weather has been blamed for an increase in the number (and severity) of natural disasters ranging from wild fires to hurricanes to flash flooding.
#
# The purpose of this project is to focus on a single city in the US, Seattle, with a goal of answering the question... "*Is weather getting noticibly more extreme?*" The decision to focus on Seattle is purely based on the fact that it happens to be where I live and have lived for the past 20 years. Anecdotally speaking, I *feel* like Seattle weather has definitely become more extreme even in that timeframe. But will the data bear that out? And... beyond 20 years, what are the trends over the last several decades?
#
# ### Dataset
# The dataset for this project comes from [NOAA](https://www.ncdc.noaa.gov/cdo-web/) (National Oceanic and Atmospheric Administration). This dataset includes a variety of daily weather attributes recorded at one specific weather station (i.e., Seattle-Tacoma Airport) starting in 1948 through 2020.
#
# For this project, we'll utilize the following data fields:
#
# * `SNOW` - Snowfall
# * `PRCP` - Precipitation
# * `AWND` - Average wind speed
# * `WSFG` - Peak gust wind speed
# * `TMAX` - Maximum temperature
# * `TMIN` - Minimum temperature
#
# ### Key Questions
# In this project, we aim to answer the overall question - "Is Seattle weather getting more extreme?". To answer this question, we'll focus on answering a few key sub-questions with the data:
#
# 1. Is the average daily high temperature increasing over time?
# 2. Is the average daily low temperature decreasing over time?
# 3. Is the average wind speed increasing over time?
# 4. Is the average annual snowfall increasing over time?
# 5. Is the number of extreme weather events increasing over time?
#
# For question 5, we'll focus on the number of weather events (min/max temps, max wind gust speed and daily snowfall) that fall outside of 2 standard deviations from the overall average in each category.
#
#
# ## 2 Setup

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Load and Preview

# %%
# Import data & preview
seattle_weather = pd.read_csv('2757387.csv')
seattle_weather.head()
# Out:
#        STATION                           NAME        DATE  AWND  FMTM  PGTM  \
# 0  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1948-01-01   NaN   NaN   NaN
# 1  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1948-01-02   NaN   NaN   NaN
# 2  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1948-01-03   NaN   NaN   NaN
# 3  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1948-01-04   NaN   NaN   NaN
# 4  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1948-01-05   NaN   NaN   NaN
#
#    PRCP  PSUN  SNOW  SNWD  ...  WDF1  WDF2  WDF5  WDFG  WDFM  WSF1  WSF2  \
# 0  0.47   NaN   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  0.59   NaN   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  0.42   NaN   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  0.31   NaN   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  0.17   NaN   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WSF5  WSFG  WSFM
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# ...

# %%
seattle_weather.shape
# Out:
# (26664, 24)

# %%
seattle_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26664 entries, 0 to 26663
# Data columns (total 24 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  26664 non-null  object
#  1   NAME     26664 non-null  object
#  2   DATE     26664 non-null  object
#  3   AWND     13513 non-null  float64
#  4   FMTM     9972 non-null   float64
#  5   PGTM     13580 non-null  float64
#  6   PRCP     26661 non-null  float64
#  7   PSUN     6821 non-null   float64
#  8   SNOW     22219 non-null  float64
#  9   SNWD     22253 non-null  float64
#  10  TAVG     5505 non-null   float64
#  11  TMAX     26664 non-null  int64
#  12  TMIN     26664 non-null  int64
#  13  TSUN     12642 non-null  float64
#  14  WDF1     1377 non-null   float64
#  15  WDF2     8949 non-null   float64
#  16  WDF5     8749 non-null   float64
#  17  WDFG     8764 non-null   float64
#  18  WDFM     9363 non-null   float64
#  19  WSF1     1377 non-null   float64
# ...

# %% [markdown]
# ## 3. Data Wrangling
#
# To prepare our data for further analysis, we'll complete the following data wrangling steps:
# 1. Drop unnecessary columns - To answer our questions, we only need a subset of the columns
# 2. Convert the 'DATE' column to datetime and set it as the index
# 3. Create some new columns to calculate a rolling annual average for each of our remaining columns
#
# ### Remove Unnecessary Columns
# To answer our key questions, we can remove a number of columns from the dataset.

# %%
# Drop unnecessary columns and columns with large number of missing values
seattle_weather = seattle_weather.dropna(thresh=8765, axis=1)
seattle_weather.drop(columns=['STATION', 'NAME', 'SNWD', 'FMTM', 'TSUN', 'WSFM', 'WDF2', 'WDFM', 'WSF2', 'PGTM'],
                     inplace=True)

# %% [markdown]
# ### Convert Date to DateTime and Set as Index

# %%
# Convert date column to datetime format and set as index
seattle_weather['DATE'] = pd.to_datetime(seattle_weather.DATE)
seattle_weather = seattle_weather.set_index('DATE')

# Check the result
seattle_weather.head()
# Out:
#             AWND  PRCP  SNOW  TMAX  TMIN  WSFG
# DATE
# 1948-01-01   NaN  0.47   0.0    51    42   NaN
# 1948-01-02   NaN  0.59   0.0    45    36   NaN
# 1948-01-03   NaN  0.42   0.0    45    35   NaN
# 1948-01-04   NaN  0.31   0.0    45    34   NaN
# 1948-01-05   NaN  0.17   0.0    45    32   NaN

# %% [markdown]
# ### Calculate Annual Rolling Averages for Weather Stats

# %%
# Compute a rolling average weather data
seattle_weather['AVG_HIGH'] = seattle_weather.TMAX.rolling(365).mean()
seattle_weather['AVG_LOW'] = seattle_weather.TMIN.rolling(365).mean()
seattle_weather['AVG_PRCP'] = seattle_weather.PRCP.rolling(365).mean()
seattle_weather['AVG_SNOW'] = seattle_weather.SNOW.rolling(365).mean()
seattle_weather['AVG_AWND'] = seattle_weather.AWND.rolling(365).mean()
seattle_weather['AVG_WSFG'] = seattle_weather.WSFG.rolling(365).mean()

# %%
seattle_weather.head()
# Out:
#             AWND  PRCP  SNOW  TMAX  TMIN  WSFG  AVG_HIGH  AVG_LOW  AVG_PRCP  \
# DATE
# 1948-01-01   NaN  0.47   0.0    51    42   NaN       NaN      NaN       NaN
# 1948-01-02   NaN  0.59   0.0    45    36   NaN       NaN      NaN       NaN
# 1948-01-03   NaN  0.42   0.0    45    35   NaN       NaN      NaN       NaN
# 1948-01-04   NaN  0.31   0.0    45    34   NaN       NaN      NaN       NaN
# 1948-01-05   NaN  0.17   0.0    45    32   NaN       NaN      NaN       NaN
#
#             AVG_SNOW  AVG_AWND  AVG_WSFG
# DATE
# 1948-01-01       NaN       NaN       NaN
# 1948-01-02       NaN       NaN       NaN
# 1948-01-03       NaN       NaN       NaN
# 1948-01-04       NaN       NaN       NaN
# 1948-01-05       NaN       NaN       NaN

# %%
seattle_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26664 entries, 1948-01-01 to 2020-12-31
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AWND      13513 non-null  float64
#  1   PRCP      26661 non-null  float64
#  2   SNOW      22219 non-null  float64
#  3   TMAX      26664 non-null  int64
#  4   TMIN      26664 non-null  int64
#  5   WSFG      8765 non-null   float64
#  6   AVG_HIGH  26300 non-null  float64
#  7   AVG_LOW   26300 non-null  float64
#  8   AVG_PRCP  25569 non-null  float64
#  9   AVG_SNOW  21486 non-null  float64
#  10  AVG_AWND  12421 non-null  float64
#  11  AVG_WSFG  8037 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 2.6 MB

# %% [markdown]
# ## 4 Exploratory Data Analysis
#
# Next, let's explore our data to establish a baseline understanding before we start answering our key questions form above.
#
# ### Data Distributions

# %%
# Plot distributions of key data fields
cols = ['AWND', 'PRCP', 'SNOW', 'TMAX', 'TMIN', 'WSFG']
seattle_weather.hist(cols,  figsize=(16,12), bins=50);

# %%
seattle_weather.hist()
# Out:
# array([[<AxesSubplot:title={'center':'AWND'}>,
#         <AxesSubplot:title={'center':'PRCP'}>,
#         <AxesSubplot:title={'center':'SNOW'}>],
#        [<AxesSubplot:title={'center':'TMAX'}>,
#         <AxesSubplot:title={'center':'TMIN'}>,
#         <AxesSubplot:title={'center':'WSFG'}>],
#        [<AxesSubplot:title={'center':'AVG_HIGH'}>,
#         <AxesSubplot:title={'center':'AVG_LOW'}>,
#         <AxesSubplot:title={'center':'AVG_PRCP'}>],
#        [<AxesSubplot:title={'center':'AVG_SNOW'}>,
#         <AxesSubplot:title={'center':'AVG_AWND'}>,
#         <AxesSubplot:title={'center':'AVG_WSFG'}>]], dtype=object)

# %%
# Plot temp
plt.figure(figsize=(16,9))

sns.lineplot(data=seattle_weather.TMIN, label='Low', alpha=0.3)
sns.lineplot(data=seattle_weather.AVG_LOW, label='Avg Low', color='blue')
sns.lineplot(data=seattle_weather.TMAX, label='High', alpha=0.3)
sns.lineplot(data=seattle_weather.AVG_HIGH, label='Avg High', color='orange')

plt.xlabel("Date", size=14)
plt.ylabel("Daily Temperatures (F)", size=14)
plt.suptitle("Seattle Daily Temperatures, 1948 to 2020", size=16, x=0.5, y=0.95)
plt.title("(with Annualized Rolling Average)", size=14, y=1.02)
plt.legend()
plt.show()

# %%
# Plot precipitation
plt.figure(figsize=(16,9))
sns.lineplot(data=seattle_weather.PRCP, label='Daily Precipitation', alpha=0.3)
sns.lineplot(data=seattle_weather.AVG_PRCP, label='Annual Rolling Avg.', color='blue')

plt.xlabel("Date", size=14)
plt.ylabel("Daily Precipitation (inches)", size=14)
plt.suptitle("Seattle Daily Precipitation, 1948 to 2020", size=16, x=0.5, y=0.95)
plt.title("(with Annualized Rolling Average)", size=14, y=1.02)
plt.legend()
plt.show()

# %%
# Plot snowfall
plt.figure(figsize=(16,9))
sns.lineplot(data=seattle_weather.SNOW, label='Daily Sanowfall', alpha=0.3)
sns.lineplot(data=seattle_weather.AVG_SNOW, label='Annual Rolling Avg.', color='blue')

plt.xlabel("Date", size=14)
plt.ylabel("Daily Snowfall (inches)", size=14)
plt.suptitle("Seattle Daily Snowfall, 1948 to 2020", size=16, x=0.5, y=0.95)
plt.title("(with Annualized Rolling Average)", size=14, y=1.02)
plt.legend()
plt.show()

# %%
# Extract year from index and 
seattle_weather["YEAR"] = seattle_weather.index.year

# %%
# Out:
# DATE
# 1948-01-01    1948
# 1948-01-02    1948
# 1948-01-03    1948
# 1948-01-04    1948
# 1948-01-05    1948
#               ...
# 2020-12-27    2020
# 2020-12-28    2020
# 2020-12-29    2020
# 2020-12-30    2020
# 2020-12-31    2020
# Name: YEAR, Length: 26664, dtype: int64
